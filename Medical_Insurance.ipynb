# %% [markdown]
# ![Health.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# First we will import our required python libraries.

# %%
import pandas as pd
import seaborn as sb
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# We will import our dataset.

# %%
df=pd.read_csv("insurance.csv")
df
# Out:
#       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1338 rows x 7 columns]

# %%
df.shape
# Out:
# (1338, 7)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1338 non-null   int64
#  1   sex       1338 non-null   object
#  2   bmi       1338 non-null   float64
#  3   children  1338 non-null   int64
#  4   smoker    1338 non-null   object
#  5   region    1338 non-null   object
#  6   charges   1338 non-null   float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 73.3+ KB

# %%
df.isnull().sum()
# Out:
# age         0
# sex         0
# bmi         0
# children    0
# smoker      0
# region      0
# charges     0
# dtype: int64

# %%
df.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %% [markdown]
# # Let's know our dataset

# %% [markdown]
# The factors which affect the charges of medical insurance depends on various parameters.
#
#
# *   Age: The age of the beneficiary
# *   Sex: Sex of the the beneficiary
#
# *   BMI: It is body mass index. In mathematical terms, the ratio of weight in kg to the square of height in meters.
# *   Children: Number of children depends on the beneficiary.
#
# *   Smoker: The smoking habit of beneficiary.
# *   Region: The residential area of the beneficiary.

# %%
df.dtypes
# Out:
# age           int64
# sex          object
# bmi         float64
# children      int64
# smoker       object
# region       object
# charges     float64
# dtype: object

# %% [markdown]
# # Data Preprocessing

# %%
df.drop_duplicates(inplace=True)

# %%
df.shape
# Out:
# (1337, 7)

# %%
df.isnull().sum()
# Out:
# age         0
# sex         0
# bmi         0
# children    0
# smoker      0
# region      0
# charges     0
# dtype: int64

# %% [markdown]
# # Data Visualisation

# %%
sb.distplot(x=df['age'])
# Out:
# <ipython-input-201-adebb0b95f4c>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sb.distplot(x=df['age'])
# <Axes: ylabel='Density'>

# %%
sb.barplot(x=df['sex'],y=df['charges'])
# Out:
# <Axes: xlabel='sex', ylabel='charges'>

# %%
sb.barplot(x=df['sex'],y=df['charges'],hue=df['children'])
# Out:
# <Axes: xlabel='sex', ylabel='charges'>

# %%
sb.barplot(x=df['sex'],y=df['charges'],hue=df['smoker'])
# Out:
# <Axes: xlabel='sex', ylabel='charges'>

# %%
sb.barplot(x=df['sex'],y=df['charges'],hue=df['region'])
# Out:
# <Axes: xlabel='sex', ylabel='charges'>

# %%
sb.distplot(x=df['bmi'])
# Out:
# <ipython-input-206-eabb01ca873a>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sb.distplot(x=df['bmi'])
# <Axes: ylabel='Density'>

# %%
a=df['region'].value_counts()
a
# Out:
# southeast    364
# southwest    325
# northwest    324
# northeast    324
# Name: region, dtype: int64

# %%
z=['southeast','southwest','northwest','northeast']
plt.pie(a,labels=z,autopct='%0.1f%%',explode=[0.1,0.01,0.01,0.01])
plt.title("Distribution of people regionwise")
plt.show()

# %%
sb.barplot(x=df['children'],y=df['age'],hue=df['sex'])
# Out:
# <Axes: xlabel='children', ylabel='age'>

# %%
sb.barplot(y=df['children'],x=df['region'],hue=df['smoker'],palette="inferno")
# Out:
# <Axes: xlabel='region', ylabel='children'>

# %%
sb.countplot(x=df['smoker'])
# Out:
# <Axes: xlabel='smoker', ylabel='count'>

# %%
sb.barplot(x=df['region'],y=df['charges'])
# Out:
# <Axes: xlabel='region', ylabel='charges'>

# %%
df['sex'].value_counts()
# Out:
# male      675
# female    662
# Name: sex, dtype: int64

# %% [markdown]
# # Data Conclusion

# %% [markdown]
# 1. Males beneficiary are charged higher than females especially having three children.
# 2. Females and males beneficiary with five children are charged less.
# 3. The beneficiary living in southeast are charged the most while southwest residentials are charged the least.
# 4. Non-smokers are taking up insurance more than smokers.
# 5. Smokers are charged higher than non-smokers.

# %% [markdown]
# # Analysis

# %%
sb.lmplot(x='age',y='bmi',data=df,hue='smoker',palette='Set1')

# %%
sb.lmplot(x='age',y='charges',data=df,hue='smoker')

# %%
sb.lmplot(x='children',y='charges',data=df,hue='smoker',palette='inferno')

# %%
sb.heatmap(df.corr())
# Out:
# <ipython-input-217-5bf5719ea17b>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sb.heatmap(df.corr())
# <Axes: >

# %% [markdown]
# # Machine Learning Model

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
df['sex']=le.fit_transform(df['sex'])
df['smoker']=le.fit_transform(df['smoker'])
df['region']=le.fit_transform(df['region'])

# %%
df
# Out:
#       age  sex     bmi  children  smoker  region      charges
# 0      19    0  27.900         0       1       3  16884.92400
# 1      18    1  33.770         1       0       2   1725.55230
# 2      28    1  33.000         3       0       2   4449.46200
# 3      33    1  22.705         0       0       1  21984.47061
# 4      32    1  28.880         0       0       1   3866.85520
# ...   ...  ...     ...       ...     ...     ...          ...
# 1333   50    1  30.970         3       0       1  10600.54830
# 1334   18    0  31.920         0       0       0   2205.98080
# 1335   18    0  36.850         0       0       2   1629.83350
# 1336   21    0  25.800         0       0       3   2007.94500
# 1337   61    0  29.070         0       1       1  29141.36030
#
# [1337 rows x 7 columns]

# %% [markdown]
# Splitting the data for train and test data set

# %%
x=df.drop(['charges'],axis=1)
y=df['charges']

# %%
from sklearn.model_selection import train_test_split as tts

# %%
x_train,x_test,y_train,y_test=tts(x,y,shuffle=True,random_state=42,test_size=0.2)

# %%
print("The shape of x train set", x_train.shape)
print("The shape of y train set",y_train.shape)
print("The shape of x test set",x_test.shape)
print("The shape of y test set",y_test.shape)
# Out:
# The shape of x train set (1069, 6)
# The shape of y train set (1069,)
# The shape of x test set (268, 6)
# The shape of y test set (268,)

# %% [markdown]
# **Feature Scaling**

# %%
x
# Out:
#       age  sex     bmi  children  smoker  region
# 0      19    0  27.900         0       1       3
# 1      18    1  33.770         1       0       2
# 2      28    1  33.000         3       0       2
# 3      33    1  22.705         0       0       1
# 4      32    1  28.880         0       0       1
# ...   ...  ...     ...       ...     ...     ...
# 1333   50    1  30.970         3       0       1
# 1334   18    0  31.920         0       0       0
# 1335   18    0  36.850         0       0       2
# 1336   21    0  25.800         0       0       3
# 1337   61    0  29.070         0       1       1
#
# [1337 rows x 6 columns]

# %%
from sklearn.linear_model import LinearRegression
lr=LinearRegression()
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %% [markdown]
# **Cross Validation**

# %%
from sklearn.model_selection import cross_val_score, cross_validate

# %%
r=cross_validate(lr,x,y,cv=5,scoring='r2',return_train_score=True)
r
# Out:
# {'fit_time': array([0.00907159, 0.00347161, 0.0033493 , 0.00405812, 0.00342894]),
#  'score_time': array([0.00292492, 0.0017879 , 0.00192285, 0.0019567 , 0.00194001]),
#  'test_score': array([0.76123487, 0.70840689, 0.77720769, 0.73365562, 0.7551376 ]),
#  'train_score': array([0.74737531, 0.75930033, 0.74326474, 0.75468466, 0.74915469])}

# %%
round(r['test_score'].mean()*100,2)
# Out:
# 74.71

# %%
r['train_score'].mean()*100
# Out:
# 75.07559465098191

# %%
df.columns
# Out:
# Index(['age', 'sex', 'bmi', 'children', 'smoker', 'region', 'charges'], dtype='object')

# %%
input_data=(19,0,27.900,0,1,3)
input=np.asarray(input_data)
data=input.reshape(1,-1)
y_predict=lr.predict(data)
y_predict
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([24739.90045487])

# %%
df['charges']
# Out:
# 0       16884.92400
# 1        1725.55230
# 2        4449.46200
# 3       21984.47061
# 4        3866.85520
#            ...
# 1333    10600.54830
# 1334     2205.98080
# 1335     1629.83350
# 1336     2007.94500
# 1337    29141.36030
# Name: charges, Length: 1337, dtype: float64
